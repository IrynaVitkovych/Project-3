# %%
# Dependencies
import pandas as pd

# %%
# Pull in IMDB Movie Data into a dataframe
imdb_movie_data = pd.read_csv('imdb_movie_data_2023.csv')

imdb_movie_data.head(10)
# Out:
#    Unnamed: 0                                         Moive Name  Rating  \
# 0           0                             Leave the World Behind     6.5
# 1           1                                              Wonka     7.4
# 2           2                                        Poor Things     8.5
# 3           3                         Killers of the Flower Moon     7.8
# 4           4                                       May December     7.0
# 5           5   The Hunger Games: The Ballad of Songbirds & S...     7.1
# 6           6                                           Napoleon     6.6
# 7           7                                        Oppenheimer     8.4
# 8           8                                      Love Actually     7.6
# 9           9                                    Candy Cane Lane     5.6
#
#       Votes  Meta Score                         Genre PG Rating  Year  \
# 0   90000.0        67.0      Drama, Mystery, Thriller         R  2023
# ...

# %%
# Remove "Unnamed: 0" column
imdb_movie_data = imdb_movie_data.drop(columns=['Unnamed: 0'])

# Possibly drop the 3 IMDB scoring columns

# %%
# Check for null values
imdb_movie_data.info()

# Remove rows with null values
imdb_movie_data = imdb_movie_data.dropna()

imdb_movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Moive Name  1950 non-null   object
#  1   Rating      1944 non-null   float64
#  2   Votes       1944 non-null   float64
#  3   Meta Score  1833 non-null   float64
#  4   Genre       1833 non-null   object
#  5   PG Rating   1874 non-null   object
#  6   Year        1950 non-null   int64
#  7   Duration    1948 non-null   object
#  8   Cast        1833 non-null   object
#  9   Director    1833 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 152.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1784 entries, 0 to 1949
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Moive Name  1784 non-null   object
#  1   Rating      1784 non-null   float64
# ...

# %%
# Split the cast column 
imdb_movie_data[['Cast 1', 'Cast 2', 'Cast 3', 'Cast 4']] = imdb_movie_data['Cast'].str.split(',', expand=True)
imdb_movie_data.head(10)
# Out:
#                                           Moive Name  Rating     Votes  \
# 0                             Leave the World Behind     6.5   90000.0
# 1                                              Wonka     7.4   24000.0
# 2                                        Poor Things     8.5    6700.0
# 3                         Killers of the Flower Moon     7.8  128000.0
# 4                                       May December     7.0   21000.0
# 5   The Hunger Games: The Ballad of Songbirds & S...     7.1   56000.0
# 6                                           Napoleon     6.6   66000.0
# 7                                        Oppenheimer     8.4  553000.0
# 8                                      Love Actually     7.6  517000.0
# 9                                    Candy Cane Lane     5.6   13000.0
#
#    Meta Score                         Genre PG Rating  Year Duration  \
# 0        67.0      Drama, Mystery, Thriller         R  2023   2h 18m
# ...

# %%
# Removing the Cast column after splitting it
imdb_movie_data = imdb_movie_data.drop(columns=['Cast'])
imdb_movie_data.head(10)
# Out:
#                                           Moive Name  Rating     Votes  \
# 0                             Leave the World Behind     6.5   90000.0
# 1                                              Wonka     7.4   24000.0
# 2                                        Poor Things     8.5    6700.0
# 3                         Killers of the Flower Moon     7.8  128000.0
# 4                                       May December     7.0   21000.0
# 5   The Hunger Games: The Ballad of Songbirds & S...     7.1   56000.0
# 6                                           Napoleon     6.6   66000.0
# 7                                        Oppenheimer     8.4  553000.0
# 8                                      Love Actually     7.6  517000.0
# 9                                    Candy Cane Lane     5.6   13000.0
#
#    Meta Score                         Genre PG Rating  Year Duration  \
# 0        67.0      Drama, Mystery, Thriller         R  2023   2h 18m
# ...

# %%
# Correct spelling on Movie Name column 
imdb_movie_data.rename(columns={'Moive Name': 'Movie Name'}, inplace=True)
imdb_movie_data.head(10)
# Out:
#                                           Movie Name  Rating     Votes  \
# 0                             Leave the World Behind     6.5   90000.0
# 1                                              Wonka     7.4   24000.0
# 2                                        Poor Things     8.5    6700.0
# 3                         Killers of the Flower Moon     7.8  128000.0
# 4                                       May December     7.0   21000.0
# 5   The Hunger Games: The Ballad of Songbirds & S...     7.1   56000.0
# 6                                           Napoleon     6.6   66000.0
# 7                                        Oppenheimer     8.4  553000.0
# 8                                      Love Actually     7.6  517000.0
# 9                                    Candy Cane Lane     5.6   13000.0
#
#    Meta Score                         Genre PG Rating  Year Duration  \
# 0        67.0      Drama, Mystery, Thriller         R  2023   2h 18m
# ...

# %%
# Correct spelling on Movie Name column 
imdb_movie_data.rename(columns={'Moive Name': 'Movie Name'}, inplace=True)
imdb_movie_data.head()
# Out:
#                     Movie Name  Rating     Votes  Meta Score  \
# 0       Leave the World Behind     6.5   90000.0        67.0
# 1                        Wonka     7.4   24000.0        66.0
# 2                  Poor Things     8.5    6700.0        86.0
# 3   Killers of the Flower Moon     7.8  128000.0        89.0
# 4                 May December     7.0   21000.0        85.0
#
#                        Genre PG Rating  Year Duration          Director  \
# 0   Drama, Mystery, Thriller         R  2023   2h 18m        Sam Esmail
# 1  Adventure, Comedy, Family        PG  2023   1h 56m         Paul King
# 2     Comedy, Drama, Romance         R  2023   2h 21m  Yorgos Lanthimos
# 3      Crime, Drama, History         R  2023   3h 26m   Martin Scorsese
# 4              Comedy, Drama         R  2023   1h 57m       Todd Haynes
#
#               Cast 1           Cast 2            Cast 3            Cast 4
# 0      Julia Roberts   Mahershala Ali       Ethan Hawke           Myha'la
# ...
