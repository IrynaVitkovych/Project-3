# %%
# dependencies
import pandas as pd

# %%
# Read in the Golden Globe data into a dataframe
golden_globe_data = pd.read_csv('Raw Data/goldenglobes.csv')

golden_globe_data.head(10)
# Out:
#                                          title  year   status  \
# 0                                   Succession  2024   Winner
# 1  Mission: Impossible - Dead Reckoning Part 1  2024  Nominee
# 2                              Last of Us, The  2024  Nominee
# 3                  Taylor Swift: The Eras Tour  2024  Nominee
# 4                         John Wick: Chapter 4  2024  Nominee
# 5                  The Super Mario Bros. Movie  2024  Nominee
# 6               Guardians of the Galaxy Vol. 3  2024  Nominee
# 7          Spider-Man: Across the Spider-Verse  2024  Nominee
# 8                                  Oppenheimer  2024  Nominee
# 9                                       Barbie  2024   Winner
#
#                                   award movie
# 0        Best Television Series - Drama   NaN
# 1  Cinematic and Box Office Achievement   NaN
# 2        Best Television Series - Drama   NaN
# 3  Cinematic and Box Office Achievement   NaN
# 4  Cinematic and Box Office Achievement   NaN
# 5  Cinematic and Box Office Achievement   NaN
# 6  Cinematic and Box Office Achievement   NaN
# 7  Cinematic and Box Office Achievement   NaN
# 8  Cinematic and Box Office Achievement   NaN
# 9  Cinematic and Box Office Achievement   NaN

# %%
# Check for null values
golden_globe_data.info()

# Find rows with null values
null_rows = golden_globe_data[golden_globe_data.isnull().any(axis=1)]
null_rows.head(10)

# Remove null values as they are not related to movie awards
golden_globe_data = golden_globe_data[golden_globe_data['title'].notna()]

golden_globe_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8630 entries, 0 to 8629
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   8610 non-null   object
#  1   year    8630 non-null   int64
#  2   status  8630 non-null   object
#  3   award   8630 non-null   object
#  4   movie   6314 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 337.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 8610 entries, 0 to 8629
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   8610 non-null   object
#  1   year    8610 non-null   int64
#  2   status  8610 non-null   object
#  3   award   8610 non-null   object
#  4   movie   6303 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 403.6+ KB

# %%
# Remove awards that contain "Television" in the string
## We are only looking at the movie golden globe awards
golden_globe_data = golden_globe_data[~golden_globe_data['award'].str.contains("Television", na=False)]

golden_globe_data
# Out:
#                                             title  year   status  \
# 1     Mission: Impossible - Dead Reckoning Part 1  2024  Nominee
# 3                     Taylor Swift: The Eras Tour  2024  Nominee
# 4                            John Wick: Chapter 4  2024  Nominee
# 5                     The Super Mario Bros. Movie  2024  Nominee
# 6                  Guardians of the Galaxy Vol. 3  2024  Nominee
# ...                                           ...   ...      ...
# 8625                                 Billy Wilder  1946   Winner
# 8626                              Angela Lansbury  1946   Winner
# 8627                             J. Carroll Naish  1946   Winner
# 8628                               Ingrid Bergman  1946   Winner
# 8629                          The House I Live In  1946   Winner
#
#                                                   award  \
# 1                  Cinematic and Box Office Achievement
# 3                  Cinematic and Box Office Achievement
# 4                  Cinematic and Box Office Achievement
# 5                  Cinematic and Box Office Achievement
# 6                  Cinematic and Box Office Achievement
# ...                                                 ...
# 8625                     Best Director - Motion Picture
# 8626  Best Performance by an Actress in a Supporting...
# 8627  Best Performance by an Actor in a Supporting R...
# 8628                          Actress In A Leading Role
# 8629              Promoting International Understanding
#
#                            movie
# 1                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# ...                          ...
# 8625            The Lost Weekend
# 8626  The Picture of Dorian Gray
# 8627           A Medal For Benny
# 8628     The Bells of St. Mary's
# 8629                         NaN
#
# [5430 rows x 5 columns]

# %%
# Check that all awards relate to movies
golden_globe_data['award'].unique()
# Out:
# array(['Cinematic and Box Office Achievement',
#        'Best Director - Motion Picture',
#        'Best Performance by a Male Actor in a Supporting Role in any Motion Picture',
#        'Best Motion Picture – Non-English Language',
#        'Best Motion Picture - Animated',
#        'Best Performance by a Male Actor in a Motion Picture – Musical or Comedy',
#        'Best Performance by a Female Actor in a Motion Picture – Musical or Comedy',
#        'Best Motion Picture - Musical or Comedy',
#        'Best Performance by a Male Actor in a Motion Picture – Drama',
#        'Best Performance by a Female Actor in a Motion Picture – Drama',
#        'Best Original Song - Motion Picture',
#        'Best Original Score - Motion Picture',
#        'Best Motion Picture - Drama',
#        'Best Performance by an Actress in a Motion Picture - Drama',
#        'Best Performance by an Actor in a Motion Picture - Drama',
#        'Best Performance by an Actress in a Motion Picture - Musical or Comedy',
#        'Best Performance by an Actor in a Motion Picture - Musical or Comedy',
#        'Best Performance by an Actress in a Supporting Role in any Motion Picture',
#        'Best Performance by an Actor in a Supporting Role in any Motion Picture',
#        'Best Screenplay - Motion Picture', 'Special Achievement Award',
#        'New Star Of The Year - Actress', 'New Star Of The Year - Actor',
#        'New Star Of The Year', 'World Film Favorites', 'Documentary',
#        'Foreign Film - English Language',
#        'Foreign Film - Foreign Language',
#        'Actress In A Leading Role - Musical Or Comedy',
#        'Samuel Goldwyn International Award',
#        'Promoting International Understanding', 'Picture - Comedy',
#        'Cinematography - Black And White', 'Cinematography - Color',
#        'International News Coverage', 'Picture - Musical',
#        'Famous Silent Filmstars', 'Juvenile Performance',
#        'Hollywood Citizenship Award',
#        'New Foreign Star Of The Year - Actress',
#        'New Foreign Star Of The Year - Actor', 'Best Outdoor Drama',
#        'Picture', 'Actor In A Leading Role', 'Cinematography',
#        'Actress In A Leading Role', 'Outstanding Use Of Color'],
#       dtype=object)

# %%
# How many rows of data left
golden_globe_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5430 entries, 1 to 8629
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5430 non-null   object
#  1   year    5430 non-null   int64
#  2   status  5430 non-null   object
#  3   award   5430 non-null   object
#  4   movie   4020 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 254.5+ KB

# %%
winners = golden_globe_data[golden_globe_data['status'] == 'Winner']
winners
# Out:
#                     title  year  status  \
# 9                  Barbie  2024  Winner
# 19                 Barbie  2024  Winner
# 23      Christopher Nolan  2024  Winner
# 33      Christopher Nolan  2024  Winner
# 46      Anatomy of a Fall  2024  Winner
# ...                   ...   ...     ...
# 8625         Billy Wilder  1946  Winner
# 8626      Angela Lansbury  1946  Winner
# 8627     J. Carroll Naish  1946  Winner
# 8628       Ingrid Bergman  1946  Winner
# 8629  The House I Live In  1946  Winner
#
#                                                   award  \
# 9                  Cinematic and Box Office Achievement
# 19                 Cinematic and Box Office Achievement
# 23                       Best Director - Motion Picture
# 33                       Best Director - Motion Picture
# 46           Best Motion Picture – Non-English Language
# ...                                                 ...
# 8625                     Best Director - Motion Picture
# 8626  Best Performance by an Actress in a Supporting...
# 8627  Best Performance by an Actor in a Supporting R...
# 8628                          Actress In A Leading Role
# 8629              Promoting International Understanding
#
#                            movie
# 9                            NaN
# 19                           NaN
# 23                   Oppenheimer
# 33                   Oppenheimer
# 46                           NaN
# ...                          ...
# 8625            The Lost Weekend
# 8626  The Picture of Dorian Gray
# 8627           A Medal For Benny
# 8628     The Bells of St. Mary's
# 8629                         NaN
#
# [1320 rows x 5 columns]

# %%
#update column name to match others in dataframes to import into SQL

winners.rename(columns={'title':'Movie Name'}, inplace=True)

winners
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_14268\3633752917.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winners.rename(columns={'title':'Movie Name'}, inplace=True)
#                Movie Name  year  status  \
# 9                  Barbie  2024  Winner
# 19                 Barbie  2024  Winner
# 23      Christopher Nolan  2024  Winner
# 33      Christopher Nolan  2024  Winner
# 46      Anatomy of a Fall  2024  Winner
# ...                   ...   ...     ...
# 8625         Billy Wilder  1946  Winner
# 8626      Angela Lansbury  1946  Winner
# 8627     J. Carroll Naish  1946  Winner
# 8628       Ingrid Bergman  1946  Winner
# 8629  The House I Live In  1946  Winner
#
#                                                   award  \
# 9                  Cinematic and Box Office Achievement
# 19                 Cinematic and Box Office Achievement
# 23                       Best Director - Motion Picture
# 33                       Best Director - Motion Picture
# 46           Best Motion Picture – Non-English Language
# ...                                                 ...
# 8625                     Best Director - Motion Picture
# 8626  Best Performance by an Actress in a Supporting...
# 8627  Best Performance by an Actor in a Supporting R...
# 8628                          Actress In A Leading Role
# 8629              Promoting International Understanding
#
#                            movie
# 9                            NaN
# 19                           NaN
# 23                   Oppenheimer
# 33                   Oppenheimer
# 46                           NaN
# ...                          ...
# 8625            The Lost Weekend
# 8626  The Picture of Dorian Gray
# 8627           A Medal For Benny
# 8628     The Bells of St. Mary's
# 8629                         NaN
#
# [1320 rows x 5 columns]

# %%
winners = winners.reset_index(drop=True)
winners
# Out:
#                Movie Name  year  status  \
# 0                  Barbie  2024  Winner
# 1                  Barbie  2024  Winner
# 2       Christopher Nolan  2024  Winner
# 3       Christopher Nolan  2024  Winner
# 4       Anatomy of a Fall  2024  Winner
# ...                   ...   ...     ...
# 1315         Billy Wilder  1946  Winner
# 1316      Angela Lansbury  1946  Winner
# 1317     J. Carroll Naish  1946  Winner
# 1318       Ingrid Bergman  1946  Winner
# 1319  The House I Live In  1946  Winner
#
#                                                   award  \
# 0                  Cinematic and Box Office Achievement
# 1                  Cinematic and Box Office Achievement
# 2                        Best Director - Motion Picture
# 3                        Best Director - Motion Picture
# 4            Best Motion Picture – Non-English Language
# ...                                                 ...
# 1315                     Best Director - Motion Picture
# 1316  Best Performance by an Actress in a Supporting...
# 1317  Best Performance by an Actor in a Supporting R...
# 1318                          Actress In A Leading Role
# 1319              Promoting International Understanding
#
#                            movie
# 0                            NaN
# 1                            NaN
# 2                    Oppenheimer
# 3                    Oppenheimer
# 4                            NaN
# ...                          ...
# 1315            The Lost Weekend
# 1316  The Picture of Dorian Gray
# 1317           A Medal For Benny
# 1318     The Bells of St. Mary's
# 1319                         NaN
#
# [1320 rows x 5 columns]

# %%
#save file to import into Postgres as csv file
winners.to_csv("./Clean Data/golden_globes_winners.csv")
