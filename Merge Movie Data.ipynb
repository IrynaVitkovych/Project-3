# %%
import pandas as pd
import numpy as np

# %%
# Files to use
movies_data = pd.read_csv('Resources/Movies.csv', encoding='utf-8')
oscar_winners = pd.read_csv('CleanData/Oscar_Winners.csv', encoding='utf-8')
goldenglobe_winners = pd.read_csv('CleanData/Golden_Globe_Winners.csv', encoding='utf-8')

# Combine the data into a single DataFrame
combine_data_df = pd.merge(movies_data, oscar_winners, how='outer', on=["Movie Name", "Movie Name"])
complete_data_df = pd.merge(combine_data_df, goldenglobe_winners, how='outer', on=["Movie Name", "Movie Name"])

complete_data_df.head(10)
# Out:
#    Unnamed: 0                    Movie Name  Rating      Votes  Meta Score  \
# 0         0.0        Leave the World Behind     6.5    90000.0        67.0
# 1         1.0                         Wonka     7.4    24000.0        66.0
# 2         2.0                  Paddington 2     7.8    90000.0        88.0
# 3         3.0                    Paddington     7.3   129000.0        77.0
# 4         4.0                   Poor Things     8.5     6700.0        86.0
# 5         5.0                 The Favourite     7.5   216000.0        91.0
# 6         6.0  The Killing of a Sacred Deer     7.0   174000.0        73.0
# 7         7.0                   The Lobster     7.1   281000.0        82.0
# 8         8.0    Killers of the Flower Moon     7.8   128000.0        89.0
# 9         9.0       The Wolf of Wall Street     8.2  1500000.0        75.0
#
#   PG Rating    Year Duration          Director  Movie ID  ...       Winner_x  \
# ...

# %%
# Columns name info
complete_data_df.columns
# Out:
# Index(['Unnamed: 0', 'Movie Name', 'Rating', 'Votes', 'Meta Score',
#        'PG Rating', 'Year', 'Duration', 'Director', 'Movie ID', 'Director ID',
#        'Oscar Winner ID', 'Winner_x', 'Award', 'Oscar Award ID',
#        'Year Ceremony_x', 'Year Film', 'Golden Globe Winner ID', 'Winner_y',
#        'Year Ceremony_y', 'Golden Globe Award', 'GG Award ID'],
#       dtype='object')

# %%
complete_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4644 entries, 0 to 4643
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2241 non-null   float64
#  1   Movie Name              4643 non-null   object
#  2   Rating                  2241 non-null   float64
#  3   Votes                   2241 non-null   float64
#  4   Meta Score              2241 non-null   float64
#  5   PG Rating               2241 non-null   object
#  6   Year                    2241 non-null   float64
#  7   Duration                2241 non-null   object
#  8   Director                2241 non-null   object
#  9   Movie ID                2241 non-null   float64
#  10  Director ID             2241 non-null   float64
#  11  Oscar Winner ID         2792 non-null   float64
#  12  Winner_x                2792 non-null   object
#  13  Award                   2792 non-null   object
# ...

# %%
# Drop unwanted columns 
columns_to_drop = ['Unnamed: 0', 'Director', 'Oscar Winner ID', 'Winner_x', 'Award', 'Year Film', 'Year Ceremony_x', 'Golden Globe Winner ID', 'Winner_y', 'Year Ceremony_y','Golden Globe Award']
complete_movies_df = complete_data_df.drop(columns=columns_to_drop)

# Rename column Year_x
complete_movies_df.rename(columns={'Year_x': 'Year'}, inplace=True)

# Convert columns to integers
columns_to_convert = ['Votes', 'Meta Score', 'Year', 'Movie ID', 'Director ID']
complete_movies_df[columns_to_convert] = complete_movies_df[columns_to_convert].fillna(0).astype(int)

complete_movies_df.head(10)
# Out:
#                      Movie Name  Rating    Votes  Meta Score PG Rating  Year  \
# 0        Leave the World Behind     6.5    90000          67         R  2023
# 1                         Wonka     7.4    24000          66        PG  2023
# 2                  Paddington 2     7.8    90000          88        PG  2017
# 3                    Paddington     7.3   129000          77        PG  2014
# 4                   Poor Things     8.5     6700          86         R  2023
# 5                 The Favourite     7.5   216000          91         R  2018
# 6  The Killing of a Sacred Deer     7.0   174000          73         R  2017
# 7                   The Lobster     7.1   281000          82         R  2015
# 8    Killers of the Flower Moon     7.8   128000          89         R  2023
# 9       The Wolf of Wall Street     8.2  1500000          75         R  2013
#
#   Duration  Movie ID  Director ID Oscar Award ID GG Award ID
# 0   2h 18m         1            1            NaN         NaN
# ...

# %%
# Drop duplicate rows
movies_df = complete_movies_df.drop_duplicates(subset=['Movie Name', 'Oscar Award ID', 'GG Award ID'])

movies_df.head(10)
# Out:
#                      Movie Name  Rating    Votes  Meta Score PG Rating  Year  \
# 0        Leave the World Behind     6.5    90000          67         R  2023
# 1                         Wonka     7.4    24000          66        PG  2023
# 2                  Paddington 2     7.8    90000          88        PG  2017
# 3                    Paddington     7.3   129000          77        PG  2014
# 4                   Poor Things     8.5     6700          86         R  2023
# 5                 The Favourite     7.5   216000          91         R  2018
# 6  The Killing of a Sacred Deer     7.0   174000          73         R  2017
# 7                   The Lobster     7.1   281000          82         R  2015
# 8    Killers of the Flower Moon     7.8   128000          89         R  2023
# 9       The Wolf of Wall Street     8.2  1500000          75         R  2013
#
#   Duration  Movie ID  Director ID Oscar Award ID GG Award ID
# 0   2h 18m         1            1            NaN         NaN
# ...

# %%
unique_movies = movies_df['Movie Name'].unique()
print(unique_movies)
print(len(unique_movies))
# Out:
# ['Leave the World Behind' 'Wonka' 'Paddington 2' ... 'The Last Chance'
#  'A Medal For Benny' 'The House I Live In']
# 3092

# %%
# Export list of Oscar Winners as CSV files.
movies_df.to_csv("CleanData/MoviesWithAwards.csv", index=False)
